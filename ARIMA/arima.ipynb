# %%
# %reload_ext autoreload
# %autoreload 2

import sys
import pandas as pd
import matplotlib.pyplot as plt
# from statsmodels.tsa.stattools import adfuller
# from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
# from sklearn.metrics import mean_squared_error
# from sklearn.model_selection import train_test_split
import numpy as np
import warnings

random_state = 42
warnings.filterwarnings('ignore')

sys.path.append('../model/')
from utils import *
from data import *
from edit import *

import torch
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
def mean_basel(sequences, split_name):
    results = []
    
    for i, seq in enumerate(sequences):
        x = seq['x'][:-1]
        x_next = seq['x'][-1]
        subject_id = seq['pid']
        
        prediction = np.mean(x)
        variance = np.var(x)
        
        error = abs(prediction - x_next)
        
        results.append({
            'subject_id': subject_id,
            'cid': seq['cid'],
            "split": split_name,
            'model': 'mean',
            'x_h': x.tolist(),
            'x_next': x_next,
            'x_pred': prediction,
            'absolute_error': error,
            'sequence_length': len(x)
        })
    
    return pd.DataFrame(results)

# %%
def create_arima_baseline_predictions(sequences, split_name):
    results = []
    
    for i, seq in enumerate(sequences):
        x = seq['x'][:-1]
        x_next = seq['x'][-1]
        subject_id = seq['pid']
        
        model = ARIMA(x, order=(1, 1, 1))
        try:
            model_fit = model.fit()
            prediction = model_fit.forecast(steps=1)[0]
        except Exception as e:
            print(f"Error fitting ARIMA model for sequence {i}: {e}")
            prediction = np.nan
            print(x)

        error = abs(prediction - x_next)
        
        results.append({
            'subject_id': subject_id,
            'code': seq['cid'],
            'split': split_name,
            'baseline_type': 'arima',
            'x_h': x.tolist(),
            'x_next': x_next,
            'x_pred': prediction,
            'absolute_error': error,
            'sequence_length': len(x)
        })
    
    return pd.DataFrame(results)

# %%
DATA_DIR
# Out:
# '../../NORMA/data/processed/'

# %%
source = 'combined'
train_seq, val_seq, test_seq = load_and_split_data(DATA_DIR, source, print_info=False)
train_dl, val_dl, test_dl = create_dataloaders(train_seq, val_seq, test_seq, batch_size=16, random_state=42)

# seqs = sample_by_key(test_seq, 1)

# %%
# Create mean baseline predictions for all splits
print("Creating mean baseline predictions...")
train_mean_df = create_mean_baseline_predictions(train_seq, 'train')
val_mean_df = create_mean_baseline_predictions(val_seq, 'val')
test_mean_df = create_mean_baseline_predictions(test_seq, 'test')

# Combine all mean baseline results
mean_baseline_df = pd.concat([train_mean_df, val_mean_df, test_mean_df], ignore_index=True)
mean_baseline_df.to_csv('predictions/mean_baseline_predictions_EHRSHOT.csv', index=False)
print(f"Mean baseline predictions created: {len(mean_baseline_df)} total")
# Out:
# Creating mean baseline predictions...
# Mean baseline predictions created: 2003074 total

# %%
# Create ARIMA baseline predictions for all splits
print("Creating ARIMA baseline predictions...")
train_arima_df = create_arima_baseline_predictions(train_seq, 'train')
val_arima_df = create_arima_baseline_predictions(val_seq, 'val')
test_arima_df = create_arima_baseline_predictions(test_seq, 'test')

# Combine all ARIMA baseline results
arima_baseline_df = pd.concat([train_arima_df, val_arima_df, test_arima_df], ignore_index=True)
mean_baseline_df.to_csv('predictions/arima_baseline_predictions_EHRSHOT.csv', index=False)
print(f"ARIMA baseline predictions created: {len(arima_baseline_df)} total")
# Out:
# Creating ARIMA baseline predictions...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[19], line 3
#       1 # Create ARIMA baseline predictions for all splits
#       2 print("Creating ARIMA baseline predictions...")
# ----> 3 train_arima_df = create_arima_baseline_predictions(train_seq, 'train')
#       4 val_arima_df = create_arima_baseline_predictions(val_seq, 'val')
#       5 test_arima_df = create_arima_baseline_predictions(test_seq, 'test')
#
# Cell In[16], line 10, in create_arima_baseline_predictions(sequences, split_name)
#       7 subject_id = seq['pid']
#       9 model = ARIMA(x, order=(1, 1, 1))
# ---> 10 model_fit = model.fit()
#      11 prediction = model_fit.forecast(steps=1)[0]
#      13 error = abs(prediction - x_next)
#
# File ~/miniconda3/envs/normal/lib/python3.9/site-packages/statsmodels/tsa/arima/model.py:395, in ARIMA.fit(self, start_params, transformed, includes_fixed, method, method_kwargs, gls, gls_kwargs, cov_type, cov_kwds, return_params, low_memory)
#     392 else:
#     393     method_kwargs.setdefault('disp', 0)
# --> 395     res = super().fit(
#     396         return_params=return_params, low_memory=low_memory,
#     397         cov_type=cov_type, cov_kwds=cov_kwds, **method_kwargs)
#     398     if not return_params:
#     399         res.fit_details = res.mlefit
#
# File ~/miniconda3/envs/normal/lib/python3.9/site-packages/statsmodels/tsa/statespace/mlemodel.py:651, in MLEModel.fit(self, start_params, transformed, includes_fixed, cov_type, cov_kwds, method, maxiter, full_output, disp, callback, return_params, optim_score, optim_complex_step, optim_hessian, flags, low_memory, **kwargs)
#     531 """
#     532 Fits the model by maximum likelihood via Kalman filter.
#     533
#    (...)
#     648 statsmodels.tsa.statespace.structural.UnobservedComponentsResults
#     649 """
#     650 if start_params is None:
# --> 651     start_params = self.start_params
#     652     transformed = True
#     653     includes_fixed = True
#
# File ~/miniconda3/envs/normal/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:953, in SARIMAX.start_params(self)
#     949     params_exog = []
#     951 # Non-seasonal ARMA component and trend
#     952 (params_trend, params_ar, params_ma,
# --> 953  params_variance) = self._conditional_sum_squares(
#     954     endog, self.k_ar, self.polynomial_ar, self.k_ma,
#     955     self.polynomial_ma, self._k_trend, trend_data,
#     956     warning_description='ARMA and trend')
#     958 # If we have estimated non-stationary start parameters but enforce
#     959 # stationarity is on, start with 0 parameters and warn
#     960 invalid_ar = (
#     961     self.k_ar > 0 and
#     962     self.enforce_stationarity and
#     963     not is_invertible(np.r_[1, -params_ar])
#     964 )
#
# File ~/miniconda3/envs/normal/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:836, in SARIMAX._conditional_sum_squares(endog, k_ar, polynomial_ar, k_ma, polynomial_ma, k_trend, trend_data, warning_description)
#     831 try:
#     832     # If we have MA terms, get residuals from an AR(k) model to use
#     833     # as data for conditional sum of squares estimates of the MA
#     834     # parameters
#     835     if k_ma > 0:
# --> 836         Y = endog[k:]
#     837         X = lagmat(endog, k, trim='both')
#     838         params_ar = np.linalg.pinv(X).dot(Y)
#
# IndexError: too many indices for array: array is 0-dimensional, but 1 were indexed
